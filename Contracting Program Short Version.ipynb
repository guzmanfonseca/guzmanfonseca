# %%
# Welcome
print('Welcome to Contracting Program based on\n',
      'the UNCITRAL Model Law on Public Procurement.')

# This function just prints a line of asterisks followed by a blank line
def separateRuns():
    print('***********************************')
    print() #blank line
    
# Part I: Enter your name and receive some directions 
print('Part I: Entering your name and receiving some directions.')
separateRuns() # Call another function

name = str(input("What's your name? My name is "))
print('If you are interested to learn more about\n',
      'public procurement, the program has several\n',
      'statements with answer options that you can choice,\n',
      'and according to your answers, the program will display\n',
      'the contracting method.\n',
      'In addition, you will learn other many interesting aspects.')
separateRuns() # Call another function

# Part II : Subject matter of the procurement description
print('Part II: Subject matter of the procurement description.\n',
      'This part of the program provides you a basic knowledge\n',
      'of the UNCITRAL Model Law of Public Procurement.')
separateRuns() # Call another function

# Contracting methods list
print('Methods of Procurement')
print("According to the article 27 of the Model Law:\n",
      "1.The procuring entity may conduct procurement by means of:\n",
     "(a) Open tendering;\n",
     "(b) Restricted tendering;\n",
     "(c) Request for quotations;\n",
     "(d) Request for proposals without negotiation;\n",
     "(e) Two-stage tendering;\n",
     "(f) Request for proposals with dialogue;\n",
     "(g) Request for proposals with consecutive negotiations;\n",
     "(h) Competitive negotiations;\n",
     "(i) Electronic reverse auction; and\n",
     "(j) Single-source procurement.\n",
     "2. The procuring entity may engage in a framework agreement\n",
     "procedure in accordance with the provisions of\n"
     "chapter VII of this Law.")
separateRuns()

# Contracting Methods
# Conditions for use
# First statement
first_statement = '1. The subject matter of the procurement is:\n'
print(first_statement)
print('a) Highly complex or specialized nature available only from a\n',
      'limited number of suppliers or contractors.')
print('b) The time and cost required to examine and evaluate a large number\n',
    'of tenders would be disproportionate to the value of the subject matter\n',
    'of the procurement.')
print('c) Readily available goods or services that are not specially produced\n',
    'or provided to the particular description of the procuring entity and\n',
    'for which there is an established market, so long as the estimated value\n',
    'of the procurement contract is less than the threshold amount set out in\n',
    'the procurement regulations.')
print('d) Considering the financial aspects of proposals separately and only\n',
    'after completion of examination and evaluation of the technical, quality\n',
    'and performance characteristics of the proposals.')
print('e) Assessing that discussions with suppliers or contractors are needed\n',
      'to refine aspects of the description of the subject matter of the procurement\n',
      'and to formulate them with the detail required under article 10 of this Law,\n',
      'and in order to allow the procuring entity to obtain the most satisfactory solution\n',
      'to its procurement needs.')
print('f) Open tendering was engaged in but no tenders were presented.')
print('g) The procurement was cancelled by the procuring entity pursuant to\n',
      'paragraph 1 of article 19 of this Law and where, in the judgement of\n',
      'the procuring entity, engaging in new open-tendering proceedings or\n',
      'a procurement method under chapter IV of this Law would be unlikely to\n',
      'result in a procurement contract.')
print('h) None of the sentences above')
separateRuns()

# User Choice to the first statement
print('Now the program will display some statements with options\n',
      'to make a choice. The purpose of this task is give information\n',
      'about the methods of procurement and their conditions of use.')
choice1 = str(input("Enter your option: ")) 
print(choice1) # Print the option choiced
separateRuns()

# Contracting method function according to your option selected
def contracting_method1():
    
    if choice1 == 'a':
        print("Contracting method: Restricted tendering")
    elif choice1 == 'b':
        print("Contracting method: Restricted tendering")
    elif choice1 == 'c':
        print("Contracting method: Request for quotations")
    elif choice1 == 'd':
        print("Contracting method: Request for proposals without negotiation")
    elif choice1 == 'e':
        print("Contracting method: Two-stage tendering")
    elif choice1 == 'f':
        print("Contracting method: Two-stage tendering")
    elif choice1 == 'g':
        print("Contracting method: Two-stage tendering")
    else:
        print("Contracting method: Open tendering")
contracting_method1()
separateRuns()

# Second statement
second_statement = '2. The subject matter of the procurement is:\n'
print(second_statement)
print('a) It is not feasible for the procuring entity to formulate\n',
      'a detailed description of the subject matter of the procurement\n',
      'in accordance with article 10 of this Law, and the procuring entity\n',
      'assesses that dialogue with suppliers or contractors is needed to obtain\n',
      'the most satisfactory solution to its procurement needs.')
print('b) The procuring entity seeks to enter into a contract for the purpose\n',
      'of research, experiment, study or development, except where the contract\n',
      'includes the production of items in quantities sufficient to establish their\n',
      'commercial viability or to recover research and development costs.')
print('c) The procuring entity determines that the selected method is the most\n',
      'appropriate method of procurement for the protection of essential security\n',
      'interests of the State.')
print('d) The procurement was cancelled by the procuring entity pursuant to\n',
      'paragraph 1 of article 19 of this Law and where, in the judgement of\n',
      'the procuring entity, engaging in new open-tendering proceedings or\n',
      'a procurement method under chapter IV of this Law would be unlikely to\n',
      'result in a procurement contract.')
separateRuns()

# User Choice to the second statement
choice2 = str(input("Enter your option: ")) 
print(choice2) # Print the option choiced
separateRuns()

# Contracting method function according to your option selected
def contracting_method2():
    
    if choice2 == 'a':
        print("Contracting method: Request for proposals with dialogue")
    elif choice2 == 'b':
        print("Contracting method: Request for proposals with dialogue")
    elif choice2 == 'c':
        print("Contracting method: Request for proposals with dialogue")
    elif choice2 == 'd':
        print("Contracting method: Request for proposals with dialogue")
            
contracting_method2()
separateRuns()

third_statement = '3. The subject matter of the procurement is:\n'
print(third_statement)
print('a) The procuring entity needs to consider the financial aspects of\n',
      'proposals separately and only after completion of examination and\n',
      'evaluation of the technical, quality and performance characteristics\n',
      'of the proposals, and it assesses that consecutive negotiations with\n',
      'suppliers or contractors are needed in order to ensure that the financial\n',
      'terms and conditions of the procurement contract are acceptable to the\n', 
      'procuring entity.')
print('b) There is an urgent need for the subject matter of the procurement,\n',
      'and engaging in open-tendering proceedings or any other competitive method\n',
      'of procurement, because of the time involved in using those methods, would\n',
      'therefore be impractical, provided that the circumstances giving rise to the\n',
      'urgency were neither foreseeable by the procuring entity nor the result of\n',
      'dilatory conduct on its part.')
print('c) Owing to a catastrophic event, there is an urgent need for the subject\n',
      'matter of the procurement, making it impractical to use open-tendering proceedings\n',
      'or any other competitive method of procurement because of the time involved in\n',
      'using those methods.')
print('d) The procuring entity determines that the use of any other competitive\n',
      'method of procurement is not appropriate for the protection of essential\n',
      'security interests of the State.')
separateRuns()

# User Choice to the third statement
choice3 = str(input("Enter your option: ")) 
print(choice3) # Print the option choiced
separateRuns()

# Contracting method function according to your option selected
def contracting_method3():
    
    if choice3 == 'a':
        print("Contracting method: Request for proposals with consecutive negotiations")
    elif choice3 == 'b':
        print("Contracting method: Competitive negotiations")
    elif choice3 == 'c':
        print("Contracting method: Competitive negotiations")
    elif choice3 == 'd':
        print("Contracting method: Competitive negotiations")
            
contracting_method3()
separateRuns()

fourth_statement = '4. The subject matter of the procurement is:\n'
print(fourth_statement)
print('a) Available only from a particular supplier or contractor,\n',
      'or a particular supplier or contractor has exclusive rights in\n',
      'respect of the subject matter of the procurement, such that no\n',
      'reasonable alternative or substitute exists, and the use of any\n',
      'other procurement method would therefore not be possible.')
print('b) Owing to a catastrophic event, there is an extremely urgent need\n',
      'for the subject matter of the procurement, and engaging in any other\n',
      'method of procurement would be impractical because of the time involved\n',
      'in using those methods.')
print('c) The procuring entity, having procured goods, equipment, technology\n',
      'or services from a supplier or contractor, determines that additional\n',
      'supplies must be procured from that supplier or contractor for reasons\n',
      'of standardization or because of the need for compatibility with existing\n',
      'goods, equipment, technology or services, taking into account the\n',
      'effectiveness of the original procurement in meeting the needs of the\n',
      'procuring entity, the limited size of the proposed procurement in relation\n',
      'to the original procurement, the reasonableness of the price and the\n',
      'unsuitability of alternatives to the goods or services in question.')
print('d) The procuring entity determines that the use of any other method of\n',
      'procurement is not appropriate for the protection of essential security\n',
      'interests of the State.')
print('e) Following public notice and adequate opportunity to comment, procurement\n',
      'from a particular supplier or contractor is necessary in order to implement\n',
      'a socio-economic policy of this State, provided that procurement from no other\n',
      'supplier or contractor is capable of promoting that policy.') 
separateRuns()

# User Choice to the fourth statement
choice4 = str(input("Enter your option: ")) 
print(choice4) # Print the option choiced
separateRuns()

# Contracting method function according to your option selected
def contracting_method4():
    
    if choice4 == 'a':
        print("Contracting method: Single-source procurement")
    elif choice4 == 'b':
        print("Contracting method: Single-source procurement")
    elif choice4 == 'c':
        print("Contracting method: Single-source procurement")
    elif choice4 == 'd':
        print("Contracting method: Single-source procurement")
    elif choice4 == 'e':
        print("Contracting method: Single-source procurement")
            
contracting_method4()
separateRuns()

# Fifth_statement
fifth_statement = '5. The subject matter of the procurement is:\n'
print(fifth_statement)
print('a) It is feasible for the procuring entity to formulate a\n',
      'detailed description of the subject matter of the procurement.')
print('b) There is a competitive market of suppliers or contractors\n',
      'anticipated to be qualified to participate in the electronic\n',
      'reverse auction, such that effective competition is ensured; and\n',
      'the criteria to be used by the procuring entity in determining the\n',
      'successful submission are quantifiable and can be expressed in\n',
      'monetary terms.')
print('c) A phase preceding the award of the procurement contract in a\n',
      'procurement method, as appropriate under the provisions of this Law;\n',
      'and the criteria to be used by the procuring entity in determining the\n',
      'successful submission are quantifiable and can be expressed in\n',
      'monetary terms.')
print('d) For award of a procurement contract in a framework agreement\n',
      'procedure with second-stage competition in accordance with the\n',
      'provisions of this Law; and the criteria to be used by the procuring\n',
      'entity in determining the successful submission are quantifiable and\n',
      'can be expressed in monetary terms.')
print('e) The need for the subject matter of the procurement is expected to\n',
      'arise on an indefinite or repeated basis during a given period of time.')
print('f) By virtue of the nature of the subject matter of the procurement,\n',
      'the need for that subject matter may arise on an urgent basis during a\n',
      'given period of time.')
separateRuns()

# User Choice to the fifth statement
choice5 = str(input("Enter your option: ")) 
print(choice5) # Print the option choiced
separateRuns()

# Contracting method function according to your option selected
def contracting_method5():
    
    if choice5 == 'a':
        print("Contracting method: Electronic reverse auction")
    elif choice5 == 'b':
        print("Contracting method: Electronic reverse auction")
    elif choice5 == 'c':
        print("Contracting method: Electronic reverse auction")
    elif choice5 == 'd':
        print("Contracting method: Electronic reverse auction")
    elif choice5 == 'e':
        print("Contracting method: Framework agreement procedure")
    elif choice5 == 'f':
        print("Contracting method: Framework agreement procedure")

contracting_method5()
separateRuns()

# Learnig more about the Model Law
# Beginning with Open Tendering contracting method
chapterIII = open('OPEN TENDERING.txt', 'r+').readlines()
consulting = 'Are you interested to read more about Open Tendering?'
print(consulting)
user_answer1 = str(input("Enter your answer: "))
if user_answer1 == 'Yes':
    specification1 = 'Do you read the whole chapter III, or any specific\n',
    'section?'
    print(specification1)
    user_answer2 = str(input("Enter your answer: "))
    if user_answer2 == 'The whole chapter III':
        print(chapterIII)
    if user_answer2 == 'A specific section':
        print('Excelent! The Chapter III has three sections:\n',
         'Solicitation of Tenders\n',
         'Presentation of Tenders\n',
         'Evaluation of Tenders\n')
        specification2 = 'Which of these are you interested in?'
        print(specification2)
        user_answer3 = str(input("Enter your answer: "))
        if user_answer3 == 'Solicitation of Tenders':
            chapterIII = list(filter(None, [item.strip('\n') for item in chapterIII]))
            print(chapterIII[:5])
        elif user_answer3 == 'Presentation of Tenders':
            chapterIII = list(filter(None, [item.strip('\n') for item in chapterIII]))
            print(chapterIII[127:164])
        elif user_answer3 == 'Evaluation of Tenders':
            chapterIII = list(filter(None, [item.strip('\n') for item in chapterIII]))
            print(chapterIII[166:239])

# Learning about other contracting methods
if user_answer1 == 'No':
    verifying = 'Would you like to read another chapter or conclude your consulting?'
    print(verifying)
    user_answer1 = str(input("Enter your answer: "))
    if user_answer1 == 'Reading another item':
        print('Excelent! The Model Law has other chapters:\n',
             'Chapter IV: Procedures for Restricted Tendering,\n',
             'Request for Quotations and Request for Proposals\n',
             'without Negotiation\n',
             'Chapter V: Procedures for two-stage tendering\n',
             'Request for proposals with dialogue\n',
             'Request for proposals with consecutive negotiations\n',
             'Competitive negotiations\n',
             'Single-source procurement\n',
             'Chapter VI: Electronic Reverse Auctions\n',
             'Chapter VII: Framework Agreement Procedures')
        specification3 = 'Which of these are you interested in?'
        print(specification3)
        user_answer4 = str(input("Enter your answer: "))
        if user_answer4 == 'Restricted Tendering':
            chapterIV = open('RESTRICTED TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[2:6])
        elif user_answer4 == 'Request for Quotations':
            chapterIV = open('RESTRICTED TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[7:19])
        elif user_answer4 == 'Request for Proposals without Negotiation':
            chapterIV = open('RESTRICTED TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[19:144])
        elif user_answer4 == 'Two-stage tendering':
            chapterIV = open('TWO-STAGE TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[3:52])
        elif user_answer4 == 'Request for proposals with dialogue':
            chapterIV = open('TWO-STAGE TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[43:214])
        elif user_answer4 == 'Request for proposals with consecutive negotiations':
            chapterIV = open('TWO-STAGE TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[214:252])
        elif user_answer4 == 'Competitive negotiations':
            chapterIV = open('TWO-STAGE TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[252:270])    
        elif user_answer4 == 'Single-source procurement':
            chapterIV = open('TWO-STAGE TENDERING AND OTHERS.txt','r+').readlines()
            chapterIV = list(filter(None, [item.strip('\n') for item in chapterIV]))
            print(chapterIV[270:276])
        elif user_answer4 == 'Electronic Reverse Auctions':
            chapterV = open('ELECTRONIC REVERSE AUCTIONS.txt','r+').readlines()
            chapterV_string = ' '.join([str(item) for item in chapterV])
            print(chapterV_string)
        elif user_answer4 == 'Framework Agreement Procedures':
            chapterVI = open('FRAMEWORK AGREEMENT PROCEDURES.txt', 'r+').readlines()
            chapterVI_string = ' '.join([str(item) for item in chapterVI])
            print(chapterVI_string)
            
if (user_answer1 == 'Consulting is over') or (user_answer1 == 'Terminated'):
    print('Let`s continue with the Part III of this program')
separateRuns() # Call another function

print('Part III: Machine Learning Model for Making Predictions')
# Making predictions about the selection of contracting method
# We are going to build a machine learning model for classification tasks
# We import the libraries needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# We import the dataset
xlsx_path = 'data_increased.xlsx'
data2 = pd.read_excel(xlsx_path)
data2.head()

# We drop a column that is not necessary
data2.drop(['Unnamed: 0'],axis=1, inplace=True)
print('The data about contracting cases is :\n',
      data2.head())
separateRuns() # Call another function

# We store the features (columns) of the observations as variable X
# as an independent variable and the target as y
X = data2[['condition', 'sourcing', 'complexity']]
y = data2['method']

# Description of the data
print('**Description of the data**\n',
      'Number of instances: 150 spread out in several classes\n',
      'Number of attributes: 9, 1 object and 8 numeric\n',
      'Attribute information:\n',
      '-case: It is the number of each case\n',
      '-rule: It refers to an article of the Public Procurement Model Law\n',
      '-condition: It refers to the conditions for use of contracting methods\n',
      'set out in the Public Procurement Model Law\n',
      '-sourcing: It refers to the suppliers o contractors in the market\n',
      '-complexity: It refers to the quality of being complex of the subject\n',
      'matter of procurement\n',
      '-workscope: It refers to the extent of activity\n',
      '-pricing model: it is a mechanism that companies use to determine\n',
      'the optimum commercial agreement between the company and the\n',
      'supplier. Definition taken from the white paper called "Unpacking\n',
      'the Best Value", written by Kate Vitasek and other researchers.\n',
      '-business model: The rationale for how an organization creates,\n',
      'delivers and captures value. Term taken from the Glossary of\n',
      'Sourcing Terms - Sourcing Industry Group.\n',
      '-method: procedure designed according to characteristics of the\n',
      'subject matter or procurement whose purpose is to select the\n',
      'supplier or contract that best satisfies the procuring entity\n',
      'needs.\n',
      '**************************\n',
      'Class:\n',
      '- open tendering\n',
      '- restricted tendering\n',
      '- request for proposals\n',
      '- two-stage tendering\n',
      '- request for proposals with dialogue\n',
      '- request for proposals with consecutive negotiations\n',
      '- competitive negotiations\n',
      '- single-soruce\n',
      '- electronic reverse auctions\n',
      '- framework agreement procedure\n',
      '********************************\n',
      'Summary statistics:\n',
      data2.describe(),'\n',
      '********************************\n',
      'Missing Attribute Values: \n',
      data2.isnull().sum())
separateRuns() # Call another function      
    
# We state the problem. We are trying to determine the contracting method
# from a set of new observations. This is a classification task. The data 
# available includes a target variable, which we have named y. 
# This is a supervised classification problem.

# we choose a model to solve the supervised classification. We have chosen
# a Decision Tree. Decision trees are widely used models for classification 
# and regression tasks. Essentially,they learn a hierarchy of if/else 
# questions, leading to a decision.

# To measure the performance of prediction, we will split the dataset into 
# training and test sets. The training set refers to data we will learn 
# from. The test set is the data we hold out and pretend not to know as 
# we would like to measure the performance of our learning procedure. 
# So, import a function that will split the dataset:

# Train_Test_Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
separateRuns() # Call another function 

# We import the decision tree classifier and train it on the training set:
# Classification
# K_Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
k = 3
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
separateRuns() # Call another function 

# We make a prediction with the test set
prediction = neigh.predict(X_test)
prediction[0:5]
separateRuns() # Call another function 

# We measure the accuracy on the test set
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, prediction))
separateRuns() # Call another function 

# Making predictions on new data
print('This program will display for you the options that you\n',
      'will select for making predictions on new data. These options\n',
      'are referred to the first three features of the data, which are\n',
      'condition, sourcing, and complexity. Recall that you should use\n',
      'open tendering as a procurement method, unless there are some of\n',
      'exceptions set out in the Model Law.\n',
      '*************************************\n',
     'The options for the feature "condition" are the following:\n',)
additional_supplies = 0
print('*Additional supplies =',additional_supplies)
print('------------------------------------------')
competitive_market_ensured = 1
print('*Competitive marked ensured =',competitive_market_ensured)
print('------------------------------------------')
extremely_urgent = 2
print('*Extremely urgent =',extremely_urgent)
print('------------------------------------------')
feasibility_for_detailed_description = 3
print('*Feasibility for description detailed =',feasibility_for_detailed_description)
print('------------------------------------------')
financial_aspects_and_consecutive_negotiations = 4
print('*Considering the financial aspects separately and assessing that\n',
      'consecutive negotiations with suppliers are needed =',
      financial_aspects_and_consecutive_negotiations)
print('------------------------------------------')
no_tenders = 5
print('*No tenders were presented =',no_tenders)
print('------------------------------------------')
no_exceptions = 6
print('*No exceptions apply =',no_exceptions)
print('------------------------------------------')
no_feasibility_and_dialogue_is_needed = 7
print('*No feasibility to formulate a detailed description of the\n',
      'the subject matter of procurement and dialogue with suppliers\n',
      'is needed =',no_feasibility_and_dialogue_is_needed)
print('------------------------------------------')
protection_of_es = 8
print('*Protection of essential security interests of the State =',
      protection_of_es)
print('------------------------------------------')
resd_contract = 9
print('*Contract for research, experiment, study or development =',
      resd_contract)
print('------------------------------------------')
time_and_cost_to_examine = 10
print('*Time and cost required to examine and evaluate a large number\n',
      'of tenders would be disproportionate to the value of the subject\n',
      'matter of the procurement=',time_and_cost_to_examine)
print('------------------------------------------')
any_cm_not_app = 11
print('*The use of any other competitive method of procurement is not\n',
      'appropiate for the protection of essential security of the State =',
      any_cm_not_app)
print('------------------------------------------')
available_goods_or_services = 12
print('*Available goods or services that are not specially produced or\n',
      'provided to the particular description of the procuring entity =',
     available_goods_or_services)
print('------------------------------------------')
award_of_pc = 13
print('*Award of a procurement contract in a framework agreement procedure\n',
      'with second-stage competition =',award_of_pc)
print('------------------------------------------')
catastrophic_event = 14
print('*Owing to a catastrophic event, there is an urgent need for the\n',
      'subject matter of the procurement =',catastrophic_event)
print('------------------------------------------')
criteria_quantifiable = 15
print('*The criteria to be used by the procuring entity in determining\n',
      'the successful submission are quantifiable and expressed in\n',
      'monetary term s=',criteria_quantifiable)
print('------------------------------------------')
exclusive_rights = 16
print('*A particular supplier or contractor has exclusive rights in\n',
      'respect of the subject matter of the procurement =',exclusive_rights)
print('------------------------------------------')
financial_aspects = 17
print('*Considering the financial aspects of proposals separately and\n',
      'only after completion of examination and evaluation of the\n',
      'technical, quality and performance characteristics of the\n',
      'proposals =',financial_aspects)
highly_complex = 18
print('*The subject matter of the procurement is highly complex or\n',
     'specialized nature =', highly_complex)
print('------------------------------------------')
particular_supplier = 19
print('*The subject matter of the procurement is available only from\n',
      'a particular supplier or contractor =',particular_supplier)
phase_preceding = 20
print('*Using an electronic reverse auction as a phase preceding\n',
      'the award of the procurement contract in a procurement\n',
      'contract =',phase_preceding)
print('------------------------------------------')
procurement_cancelled = 21
print('*The procurement was cancelled by the procuring entity =\n',
     procurement_cancelled)
print('------------------------------------------')
new_op_or_pc = 22
print('*Engaging in new open-tendering proceedings or a procurement\n',
      'method would be unlikely to result in a procurement contract\n',
      '=',new_op_or_pc)
print('------------------------------------------')
repeated_basis = 23
print('*The need for the subject matter of the procurement is\n',
      'expected to arise on an indefinite or repeated basis\n',
      'during a given period of time =',repeated_basis)
print('------------------------------------------')
socio_economic_policy = 24
print('*Procurement from a particular supplier or contractor\n',
      'is necessary in order to implement a socio_economic\n',
      'policy =',socio_economic_policy)
print('------------------------------------------')
urgent_basis = 25
print('*By virtue of the nature of the subject matter of the\n',
      'procurement, the need for that subject matter may arise\n',
      'on an urgent basis during a given period of time =',urgent_basis)
print('------------------------------------------')
print('The options for the feature "sourcing" are the following:\n',)
limited = 0
print('*Limited number of suppliers or contractors =',limited)
print('------------------------------------------')
many_suppliers = 1
print('*Many suppliers or contractors =',many_suppliers)
print('------------------------------------------')
many_suppliers_or_several = 2
print('*Many suppliers, or several suppliers =',many_suppliers_or_several)
print('------------------------------------------')
one_supplier = 3
print('*Sourcing from a particular supplier =',one_supplier)
print('------------------------------------------')
several_suppliers = 4
print('*Several suppliers =',several_suppliers)
print('------------------------------------------')
print('The options for the feature "complexity" are the following:\n',)
high_complexity = 0
print('*The subject matter of procurement is highly complex =',
      high_complexity)
print('------------------------------------------')
low_complexity = 1
print('*The subject matter of procurement is low complexity =',
      low_complexity)
print('------------------------------------------')
low_or_medium = 2
print('*The complexity could be low or medium =',low_or_medium)
print('------------------------------------------')
medium = 3
print('*The complexity could be medium =',medium)
medium_or_high = 4
print('*The complexity could be medium or high =',medium_or_high)
print('------------------------------------------')
separateRuns() # Call another function

# Making predictions on data provided by the user
print('This part of the contracting program pretends to provide\n',
     'you a tool for making predictions about the procurement\n',
     'method to be chosen using data given by you.')
separateRuns() # Call another function

print('Remenber that you have already known the data characteristics\n',
      'employed by this contracting program. Each of the features has\n',
      'assigned a numeric value. This program will ask you to pick up\n',
      'a value for each feature. Example: condition: 6, sourcing: 1,\n',
      'complexity: 3.')
condition = int(input('Enter your option for condition: '))
sourcing = int(input('Enter your option for sourcing: '))
complexity= int(input('Enter your option for complexity: '))
X_new = np.array([[condition, sourcing, complexity]])
prediction = neigh.predict(X_new)
string_prediction = ' '.join([str(item) for item in prediction])
print('The contracting method could be', string_prediction)
